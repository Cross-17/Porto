# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import xgboost as xgb

cwd=os.getcwd()+'/'

def gini(actual, pred, cmpcol = 0, sortcol = 1):
    assert( len(actual) == len(pred) )
    all = np.asarray(np.c_[ actual, pred, np.arange(len(actual)) ], dtype=np.float)
    all = all[ np.lexsort((all[:,2], -1*all[:,1])) ]
    totalLosses = all[:,0].sum()
    giniSum = all[:,0].cumsum().sum() / totalLosses
    
    giniSum -= (len(actual) + 1) / 2.
    return giniSum / len(actual)

def gini_normalized(a, p):
    return gini(a, p) / gini(a, a)

def gini_xgb(preds, dtrain):
    labels = dtrain.get_label()
    gini_score = gini_normalized(labels, preds)
    return [('gini', gini_score)]

df_train = pd.read_csv('input/train.csv')
df_test = pd.read_csv('input/test.csv')

target_train = df_train['target'].values
id_test = df_test['id'].values

df_train=df_train.drop(['target','id'],axis=1)
df_test=df_test.drop(['id'], axis = 1)
combine= pd.concat([df_train,df_test],axis=0)

# Performing one hot encoding
cat_features = [a for a in combine.columns if a.endswith('cat')]
for column in cat_features:
	temp=pd.get_dummies(pd.Series(combine[column]))
	combine=pd.concat([combine,temp],axis=1)
	combine=combine.drop([column],axis=1)

df_train=combine[:df_train.shape[0]]
df_test=combine[df_train.shape[0]:]

train = np.array(df_train)
test = np.array(df_test)

print ("The train shape is:",train.shape)
print ('The test shape is:',test.shape)

xgb_preds = []


K = 5
kf = KFold(n_splits = K, random_state = 3228,shuffle=True)


for train_index, test_index in kf.split(train):
    train_X, valid_X = train[train_index], train[test_index]
    train_y, valid_y = target_train[train_index], target_train[test_index]

    # params configuration also from the1owl's kernel
    # https://www.kaggle.com/the1owl/forza-baseline
    xgb_params = {'eta': 0.02, 'max_depth': 5, 'subsample': 0.9, 'colsample_bytree': 0.9, 'objective': 'binary:logistic', 'eval_metric': 'auc', 'seed': 99, 'silent': True}

    d_train = xgb.DMatrix(train_X, train_y)
    d_valid = xgb.DMatrix(valid_X, valid_y)
    d_test = xgb.DMatrix(test)
    
    watchlist = [(d_train, 'train'), (d_valid, 'valid')]
    model = xgb.train(xgb_params, d_train, 5000,  watchlist, feval=gini_xgb, maximize=True, verbose_eval=50, early_stopping_rounds=100)
                        
    xgb_pred = model.predict(d_test)
    xgb_preds.append(list(xgb_pred))
    
    
    
preds=[]
for i in range(len(xgb_preds[0])):
    sum=0
    for j in range(K):
        sum+=xgb_preds[j][i]
    preds.append(sum / K)

output = pd.DataFrame({'id': id_test, 'target': preds})
output.to_csv("{}-foldCV_avg_sub.csv".format(K), index=False)
# Out:
# ('The train shape is:', (595212L, 227L))
# ('The test shape is:', (892816L, 227L))
# Will train until valid error hasn't decreased in 100 rounds.
# [0]	train-gini:0.214903	valid-gini:0.205533
# [50]	train-gini:0.256607	valid-gini:0.238496
# [100]	train-gini:0.264550	valid-gini:0.242310
# [150]	train-gini:0.280591	valid-gini:0.249929
# [200]	train-gini:0.301085	valid-gini:0.257894
# [250]	train-gini:0.315065	valid-gini:0.262219
# [300]	train-gini:0.327778	valid-gini:0.266954
# [350]	train-gini:0.338401	valid-gini:0.268910
# [400]	train-gini:0.349276	valid-gini:0.269821
# [450]	train-gini:0.358634	valid-gini:0.270666
# [500]	train-gini:0.367106	valid-gini:0.270535
# [550]	train-gini:0.374869	valid-gini:0.270841
# [600]	train-gini:0.382098	valid-gini:0.270914
# [650]	train-gini:0.388987	valid-gini:0.270602
# [700]	train-gini:0.396089	valid-gini:0.270335
# Stopping. Best iteration:
# [630]	train-gini:0.385848	valid-gini:0.271063
#
# Will train until valid error hasn't decreased in 100 rounds.
# [0]	train-gini:0.205793	valid-gini:0.208587
# [50]	train-gini:0.254983	valid-gini:0.251809
# [100]	train-gini:0.263073	valid-gini:0.256734
# [150]	train-gini:0.279606	valid-gini:0.265254
# [200]	train-gini:0.298436	valid-gini:0.274695
# [250]	train-gini:0.313354	valid-gini:0.279717
# [300]	train-gini:0.325553	valid-gini:0.283242
# [350]	train-gini:0.336910	valid-gini:0.285318
# [400]	train-gini:0.346806	valid-gini:0.286955
# [450]	train-gini:0.356250	valid-gini:0.287604
# [500]	train-gini:0.365061	valid-gini:0.288136
# [550]	train-gini:0.372935	valid-gini:0.289090
# [600]	train-gini:0.381131	valid-gini:0.289327
# [650]	train-gini:0.389135	valid-gini:0.289132
# Stopping. Best iteration:
# [588]	train-gini:0.379275	valid-gini:0.289499
#
# Will train until valid error hasn't decreased in 100 rounds.
# [0]	train-gini:0.214749	valid-gini:0.202330
# [50]	train-gini:0.254820	valid-gini:0.238610
# [100]	train-gini:0.266221	valid-gini:0.247238
# [150]	train-gini:0.280087	valid-gini:0.256761
# [200]	train-gini:0.298043	valid-gini:0.268085
# [250]	train-gini:0.312731	valid-gini:0.275718
# [300]	train-gini:0.324922	valid-gini:0.281404
# [350]	train-gini:0.335470	valid-gini:0.284568
# [400]	train-gini:0.345490	valid-gini:0.286438
# [450]	train-gini:0.354619	valid-gini:0.287547
# [500]	train-gini:0.363610	valid-gini:0.288359
# [550]	train-gini:0.372165	valid-gini:0.289027
# [600]	train-gini:0.379870	valid-gini:0.289285
# [650]	train-gini:0.387427	valid-gini:0.289863
# [700]	train-gini:0.394244	valid-gini:0.290075
# [750]	train-gini:0.401464	valid-gini:0.290583
# [800]	train-gini:0.408089	valid-gini:0.290491
# [850]	train-gini:0.414641	valid-gini:0.290478
# [900]	train-gini:0.421228	valid-gini:0.290271
# Stopping. Best iteration:
# [825]	train-gini:0.411278	valid-gini:0.290662
#
# Will train until valid error hasn't decreased in 100 rounds.
# [0]	train-gini:0.219133	valid-gini:0.191754
# [50]	train-gini:0.257166	valid-gini:0.228464
# [100]	train-gini:0.268431	valid-gini:0.237713
# [150]	train-gini:0.281206	valid-gini:0.247616
# [200]	train-gini:0.298129	valid-gini:0.257878
# [250]	train-gini:0.313652	valid-gini:0.266198
# [300]	train-gini:0.326085	valid-gini:0.270890
# [350]	train-gini:0.337369	valid-gini:0.274147
# [400]	train-gini:0.347282	valid-gini:0.276172
# [450]	train-gini:0.356313	valid-gini:0.276888
# [500]	train-gini:0.365341	valid-gini:0.277579
# [550]	train-gini:0.373385	valid-gini:0.277939
# [600]	train-gini:0.381343	valid-gini:0.278449
# [650]	train-gini:0.389181	valid-gini:0.278906
# [700]	train-gini:0.396295	valid-gini:0.278894
# [750]	train-gini:0.403852	valid-gini:0.278635
# Stopping. Best iteration:
# [653]	train-gini:0.389788	valid-gini:0.279040
#
# Will train until valid error hasn't decreased in 100 rounds.
# [0]	train-gini:0.214609	valid-gini:0.208194
# [50]	train-gini:0.257748	valid-gini:0.240936
# [100]	train-gini:0.267019	valid-gini:0.247275
# [150]	train-gini:0.279919	valid-gini:0.253679
# [200]	train-gini:0.298293	valid-gini:0.263258
# [250]	train-gini:0.313189	valid-gini:0.270640
# [300]	train-gini:0.325364	valid-gini:0.276362
# [350]	train-gini:0.336269	valid-gini:0.278855
# [400]	train-gini:0.345858	valid-gini:0.280177
# [450]	train-gini:0.354998	valid-gini:0.281860
# [500]	train-gini:0.363038	valid-gini:0.283066
# [550]	train-gini:0.370841	valid-gini:0.283437
# [600]	train-gini:0.379592	valid-gini:0.283782
# [650]	train-gini:0.387176	valid-gini:0.284142
# [700]	train-gini:0.394893	valid-gini:0.284609
# [750]	train-gini:0.402028	valid-gini:0.284927
# [800]	train-gini:0.409034	valid-gini:0.284778
# [850]	train-gini:0.415574	valid-gini:0.284737
# Stopping. Best iteration:
# [751]	train-gini:0.402138	valid-gini:0.284957
